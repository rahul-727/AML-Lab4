# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul-727/AML-Lab4/blob/main/2348544_AML_LAB4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The dataset contains outdoor temperature and pressure data between the duration as given in the
# timestamp. The dataset is presented in OS_time, temperature, pressure humidity and actual date and
# time format. Interesting patterns between temperatures, pressure can be found for understanding the
# humidity or rainfall during the given period. This can also be used to understand environmental
# changes over time.
# 1. Consider Temperature as predictor and the target as pressure
# 2. Build a model using polynomial regression with at least 6 different degrees with 3 different
# train-test split as 66-44, 70-30, 80-20.
# 3. Calculate R2 square. Mean Squared Error, Mean Absolute Error and validate your model
# 4. Provide suitable inferences on the model created.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import zscore
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import  PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
data = pd.read_csv('/content/Program_4_Dataset.csv')
data.head(5)
# Out:
#    index  OS_Time_Stamp  Temperature  Pressure  Humidity  \
# 0      0     1456761674         17.7    1015.2      76.4
# 1      1     1456761733         17.7    1015.3      76.4
# 2      2     1456761792         17.7    1015.3      76.5
# 3      3     1456761853         17.7    1015.3      76.7
# 4      4     1456761912         17.6    1015.2      76.8
#
#                    TimeStamp
# 0  2016-03-01 00:01:14+08:00
# 1  2016-03-01 00:02:13+08:00
# 2  2016-03-01 00:03:12+08:00
# 3  2016-03-01 00:04:13+08:00
# 4  2016-03-01 00:05:12+08:00

# %%
data.isnull().sum()
# Out:
# index            0
# OS_Time_Stamp    0
# Temperature      0
# Pressure         0
# Humidity         0
# TimeStamp        0
# dtype: int64

# %%
X = data[['Temperature']].values
Y = data['Pressure'].values

# %%
plt.scatter(X,Y,color='b')
plt.xlabel('X Points')
plt.ylabel('Y Points')
# Out:
# Text(0, 0.5, 'Y Points')

# %% [markdown]
# # Train-test split as 66-44

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X, Y, test_size=0.34, random_state=42)

# %% [markdown]
# # For Polynomial degree 2

# %%
poly1 = PolynomialFeatures(degree=2)
X_train_p = poly1.fit_transform(X_train1)
X_test_p = poly1.transform(X_test1)

model1 = LinearRegression()
model1.fit(X_train_p, y_train1)

y_pred = model1.predict(X_test_p)

print('For degree = 2')
r2 = r2_score(y_test1, y_pred)
print(f'R-squared: {r2}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test1, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test1, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# For degree = 2
# R-squared: 0.6266694111938397
# Mean Squared Error: 26.38216497069319
# Mean Absolute Error: 3.688665149353792

# %%
plt.scatter(X_train1,model1.predict(X_train_p))
plt.scatter(X_train1,y_train1)

# %% [markdown]
# # For Polynomial degree 3

# %%
poly2 = PolynomialFeatures(degree=3)
X_train_p = poly2.fit_transform(X_train1)
X_test_p = poly2.transform(X_test1)

model2 = LinearRegression()
model2.fit(X_train_p, y_train1)

y_pred = model2.predict(X_test_p)

print('For degree = 3')
r2 = r2_score(y_test1, y_pred)
print(f'R-squared: {r2}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test1, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test1, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# For degree = 3
# R-squared: 0.6429539020521366
# Mean Squared Error: 25.231388320804474
# Mean Absolute Error: 3.7469996398551415

# %%
plt.scatter(X_train1,model2.predict(X_train_p))
plt.scatter(X_train1,y_train1)

# %% [markdown]
# # Train-test split as 70-30

# %%
X_train2, X_test2, y_train2, y_test2 = train_test_split(X, Y, test_size=0.3, random_state=42)

# %% [markdown]
# # For Polynomial degree 4

# %%
poly3 = PolynomialFeatures(degree=4)
X_train_p = poly3.fit_transform(X_train2)
X_test_p = poly3.transform(X_test2)

model3 = LinearRegression()
model3.fit(X_train_p, y_train2)

y_pred = model3.predict(X_test_p)

print('For degree = 4')
r2 = r2_score(y_test2, y_pred)
print(f'R-squared: {r2}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test2, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test2, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# For degree = 4
# R-squared: 0.6941666046410397
# Mean Squared Error: 21.679295208217564
# Mean Absolute Error: 3.1852525641917366

# %%
plt.scatter(X_train2,model3.predict(X_train_p))
plt.scatter(X_train2,y_train2)

# %% [markdown]
# # For Polynomial degree 5

# %%
poly4 = PolynomialFeatures(degree=5)
X_train_p = poly4.fit_transform(X_train2)
X_test_p = poly4.transform(X_test2)

model4 = LinearRegression()
model4.fit(X_train_p, y_train2)

y_pred = model4.predict(X_test_p)

print('For degree = 5')
r2 = r2_score(y_test2, y_pred)
print(f'R-squared: {r2}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test2, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test2, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# For degree = 5
# R-squared: 0.7042085681914689
# Mean Squared Error: 20.96746093640956
# Mean Absolute Error: 3.3119410844488186

# %%
plt.scatter(X_train2,model4.predict(X_train_p))
plt.scatter(X_train2,y_train2)

# %% [markdown]
# # Train-test split as 80-20

# %%
X_train3, X_test3, y_train3, y_test3 = train_test_split(X, Y, test_size=0.2, random_state=42)

# %% [markdown]
# # For Polynomial degree 6

# %%
poly5 = PolynomialFeatures(degree=6)
X_train_p = poly5.fit_transform(X_train3)
X_test_p = poly5.transform(X_test3)

model5 = LinearRegression()
model5.fit(X_train_p, y_train3)

y_pred = model5.predict(X_test_p)

print('For degree = 6')
r2 = r2_score(y_test3, y_pred)
print(f'R-squared: {r2}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test3, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test3, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# For degree = 6
# R-squared: 0.6955199132228507
# Mean Squared Error: 21.615369062582992
# Mean Absolute Error: 3.2066844729492647

# %%
plt.scatter(X_train3,model5.predict(X_train_p))
plt.scatter(X_train3,y_train3)

# %% [markdown]
# # For Polynomial degree 7

# %%
poly6 = PolynomialFeatures(degree=7)
X_train_p = poly3.fit_transform(X_train3)
X_test_p = poly3.transform(X_test3)

model6 = LinearRegression()
model6.fit(X_train_p, y_train3)

y_pred = model6.predict(X_test_p)

print('For degree = 7')
r2 = r2_score(y_test3, y_pred)
print(f'R-squared: {r2}')

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test3, y_pred)
print(f'Mean Squared Error: {mse}')

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test3, y_pred)
print(f'Mean Absolute Error: {mae}')
# Out:
# For degree = 7
# R-squared: 0.6724506321807433
# Mean Squared Error: 23.25308215249868
# Mean Absolute Error: 3.2670828201715523

# %%
plt.scatter(X_train3,model6.predict(X_train_p))
plt.scatter(X_train3,y_train3)
